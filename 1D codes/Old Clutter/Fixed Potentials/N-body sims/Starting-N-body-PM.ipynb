# %%
#Import External Libraries
import numpy as np
import matplotlib.pyplot as plt
import os 
import cv2 
from PIL import Image 

#Import My Library
My_Module_PATH = "C:\\Users\\boris\\OneDrive - Queen's University\\Documents\\JOB_Files\\McDonald Institute Fellowship\\Research\\Coding\\1D codes"
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, My_Module_PATH)
from OneD_module import *

#Set up Directory for saving files/images/videos
# Will not rename this again
Directory = "C:\\Users\\boris\\OneDrive - Queen's University\\Documents\\JOB_Files\\McDonald Institute Fellowship\\Research\\Coding\\1D codes\\Fixed Potentials\\N-Body sims"

# %%
class star:
    def __init__(self,id,mass,x,v):
        self.id = id #identification number
        self.mass = mass #mass of star
        self.x = x #it's "instantaneous" position
        self.v = v #it's "instantaneous" velocity
        #self.bin = bin #bin it resides in: index value between 0 and N-1

    def evolve_star_dynamics(self,g,dt): #g: acceleration, dt: time-step
        a = g(self.x)
        self.v += 0.5*dt*a # KICK evolve velocity forward by half time-step
        
        self.x += self.v*dt #DRIFT the position

        a = g(self.x)
        self.v += 0.5*dt*a #KICK to get full new velocity(this will change for self-gravitating system)

# %% [markdown]
# # One Particle In Harmonic Potential:

# %%
N = 10**3
L = 20
x_array = np.linspace(-L/2,L/2,N)
dx = L/(N-1)
hbar = 1
m = 2

#Set a fixed potential
a=10
phi = x_array**2 / (2*a)#np.zeros_like(x) # 

#can analytically find the acceleration:
def g(x):
    return -(x/a)/m

x_0 = -L/4
v_0 = 0
my_star = star(0,m,x_0,v_0) #0-th star, mass m, initial pos., veloc.

print(my_star.x) 

positions = np.array([my_star.x])
velocities = np.array([my_star.v])

dt = 0.1
t_stop = 20
time = 0
while time <= t_stop:
    #x_current = my_star.x
    #print(x_current)
    my_star.evolve_star_dynamics(g,dt)

    positions = np.append(positions,my_star.x)
    velocities = np.append(velocities,my_star.v)

    time += dt
print("Done Calculation. Now Plotting.")

folder_name = "SingleParticle_Images"
os.chdir(Directory + "/" + folder_name)

x_lim = [np.min(positions),np.max(positions)]
y_lim = [np.min(velocities),np.max(velocities)]

for i in range(len(positions)):
    x = positions[i]
    v = velocities[i]

    fig,ax = plt.subplots(1,2)
    plt.suptitle(f"Time {round(dt*i,1)}")
    
    ax[0].plot(x,0,"bo")
    ax[0].plot(x_array,phi,label = "Potential")
    ax[0].set_xlim(x_lim)
    #ax[0].set_ylim([np.min(positions),np.max(positions)])
    ax[0].legend()

    ax[1].plot(x,v,"bo")
    ax[1].set_xlim(x_lim)
    ax[1].set_ylim(y_lim)
    #ax[1].legend()
    
    #now save it as a .jpg file:
    folder = Directory + "\\" + folder_name
    filename = 'ToyModelPlot' + str(i+1).zfill(4) + '.jpg';
    plt.savefig(folder + "\\" + filename)  #save this figure (includes both subplots)
    
    plt.close() #close plot so it doesn't overlap with the next one

video_name = "SingleParticle_SHO_video.mp4"
animate(Directory,folder_name,video_name,dt)
# Out:
# -5.0
# Done Calculation. Now Plotting.
# ['ToyModelPlot0001.jpg', 'ToyModelPlot0002.jpg', 'ToyModelPlot0003.jpg', 'ToyModelPlot0004.jpg', 'ToyModelPlot0005.jpg', 'ToyModelPlot0006.jpg', 'ToyModelPlot0007.jpg', 'ToyModelPlot0008.jpg', 'ToyModelPlot0009.jpg', 'ToyModelPlot0010.jpg', 'ToyModelPlot0011.jpg', 'ToyModelPlot0012.jpg', 'ToyModelPlot0013.jpg', 'ToyModelPlot0014.jpg', 'ToyModelPlot0015.jpg', 'ToyModelPlot0016.jpg', 'ToyModelPlot0017.jpg', 'ToyModelPlot0018.jpg', 'ToyModelPlot0019.jpg', 'ToyModelPlot0020.jpg', 'ToyModelPlot0021.jpg', 'ToyModelPlot0022.jpg', 'ToyModelPlot0023.jpg', 'ToyModelPlot0024.jpg', 'ToyModelPlot0025.jpg', 'ToyModelPlot0026.jpg', 'ToyModelPlot0027.jpg', 'ToyModelPlot0028.jpg', 'ToyModelPlot0029.jpg', 'ToyModelPlot0030.jpg', 'ToyModelPlot0031.jpg', 'ToyModelPlot0032.jpg', 'ToyModelPlot0033.jpg', 'ToyModelPlot0034.jpg', 'ToyModelPlot0035.jpg', 'ToyModelPlot0036.jpg', 'ToyModelPlot0037.jpg', 'ToyModelPlot0038.jpg', 'ToyModelPlot0039.jpg', 'ToyModelPlot0040.jpg', 'ToyModelPlot0041.jpg', 'ToyModelPlot0042.jpg', 'ToyModelPlot0043.jpg', 'ToyModelPlot0044.jpg', 'ToyModelPlot0045.jpg', 'ToyModelPlot0046.jpg', 'ToyModelPlot0047.jpg', 'ToyModelPlot0048.jpg', 'ToyModelPlot0049.jpg', 'ToyModelPlot0050.jpg', 'ToyModelPlot0051.jpg', 'ToyModelPlot0052.jpg', 'ToyModelPlot0053.jpg', 'ToyModelPlot0054.jpg', 'ToyModelPlot0055.jpg', 'ToyModelPlot0056.jpg', 'ToyModelPlot0057.jpg', 'ToyModelPlot0058.jpg', 'ToyModelPlot0059.jpg', 'ToyModelPlot0060.jpg', 'ToyModelPlot0061.jpg', 'ToyModelPlot0062.jpg', 'ToyModelPlot0063.jpg', 'ToyModelPlot0064.jpg', 'ToyModelPlot0065.jpg', 'ToyModelPlot0066.jpg', 'ToyModelPlot0067.jpg', 'ToyModelPlot0068.jpg', 'ToyModelPlot0069.jpg', 'ToyModelPlot0070.jpg', 'ToyModelPlot0071.jpg', 'ToyModelPlot0072.jpg', 'ToyModelPlot0073.jpg', 'ToyModelPlot0074.jpg', 'ToyModelPlot0075.jpg', 'ToyModelPlot0076.jpg', 'ToyModelPlot0077.jpg', 'ToyModelPlot0078.jpg', 'ToyModelPlot0079.jpg', 'ToyModelPlot0080.jpg', 'ToyModelPlot0081.jpg', 'ToyModelPlot0082.jpg', 'ToyModelPlot0083.jpg', 'ToyModelPlot0084.jpg', 'ToyModelPlot0085.jpg', 'ToyModelPlot0086.jpg', 'ToyModelPlot0087.jpg', 'ToyModelPlot0088.jpg', 'ToyModelPlot0089.jpg', 'ToyModelPlot0090.jpg', 'ToyModelPlot0091.jpg', 'ToyModelPlot0092.jpg', 'ToyModelPlot0093.jpg', 'ToyModelPlot0094.jpg', 'ToyModelPlot0095.jpg', 'ToyModelPlot0096.jpg', 'ToyModelPlot0097.jpg', 'ToyModelPlot0098.jpg', 'ToyModelPlot0099.jpg', 'ToyModelPlot0100.jpg', 'ToyModelPlot0101.jpg', 'ToyModelPlot0102.jpg', 'ToyModelPlot0103.jpg', 'ToyModelPlot0104.jpg', 'ToyModelPlot0105.jpg', 'ToyModelPlot0106.jpg', 'ToyModelPlot0107.jpg', 'ToyModelPlot0108.jpg', 'ToyModelPlot0109.jpg', 'ToyModelPlot0110.jpg', 'ToyModelPlot0111.jpg', 'ToyModelPlot0112.jpg', 'ToyModelPlot0113.jpg', 'ToyModelPlot0114.jpg', 'ToyModelPlot0115.jpg', 'ToyModelPlot0116.jpg', 'ToyModelPlot0117.jpg', 'ToyModelPlot0118.jpg', 'ToyModelPlot0119.jpg', 'ToyModelPlot0120.jpg', 'ToyModelPlot0121.jpg', 'ToyModelPlot0122.jpg', 'ToyModelPlot0123.jpg', 'ToyModelPlot0124.jpg', 'ToyModelPlot0125.jpg', 'ToyModelPlot0126.jpg', 'ToyModelPlot0127.jpg', 'ToyModelPlot0128.jpg', 'ToyModelPlot0129.jpg', 'ToyModelPlot0130.jpg', 'ToyModelPlot0131.jpg', 'ToyModelPlot0132.jpg', 'ToyModelPlot0133.jpg', 'ToyModelPlot0134.jpg', 'ToyModelPlot0135.jpg', 'ToyModelPlot0136.jpg', 'ToyModelPlot0137.jpg', 'ToyModelPlot0138.jpg', 'ToyModelPlot0139.jpg', 'ToyModelPlot0140.jpg', 'ToyModelPlot0141.jpg', 'ToyModelPlot0142.jpg', 'ToyModelPlot0143.jpg', 'ToyModelPlot0144.jpg', 'ToyModelPlot0145.jpg', 'ToyModelPlot0146.jpg', 'ToyModelPlot0147.jpg', 'ToyModelPlot0148.jpg', 'ToyModelPlot0149.jpg', 'ToyModelPlot0150.jpg', 'ToyModelPlot0151.jpg', 'ToyModelPlot0152.jpg', 'ToyModelPlot0153.jpg', 'ToyModelPlot0154.jpg', 'ToyModelPlot0155.jpg', 'ToyModelPlot0156.jpg', 'ToyModelPlot0157.jpg', 'ToyModelPlot0158.jpg', 'ToyModelPlot0159.jpg', 'ToyModelPlot0160.jpg', 'ToyModelPlot0161.jpg', 'ToyModelPlot0162.jpg', 'ToyModelPlot0163.jpg', 'ToyModelPlot0164.jpg', 'ToyModelPlot0165.jpg', 'ToyModelPlot0166.jpg', 'ToyModelPlot01 ...

# %% [markdown]
# # FOR MANY BODIES:

# %%
N = 10**3
L = 10
x = np.linspace(-L/2,L/2,N)
dx = L/(N-1)

bin_counts = np.array([0 for i in range(N-1)])

Num_stars = 100
m = 1 #mass of each star

#Set initial distribution on grid
b = 0 #center at zero
std = 1 #standard deviation of 1
x_0 = np.random.normal(b,std,Num_stars) #initial positions sampled from normal distribution
stars = [star(i,m,x_0[i],0) for i in range(len(x_0))] #create list of normally distributed stars, zero initial speed

#Set a fixed potential
a=10
phi = x_array**2 / (2*a)#np.zeros_like(x) # 

#can analytically find the acceleration:
def g(x):
    return -(x/a)/m

folder_name = "ManyParticles_Images"
os.chdir(Directory + "\\" + folder_name)

dt = 0.1
t_stop = 20
time = 0
i = 0 #counter, for saving images
while time <= t_stop:
    fig,ax = plt.subplots(1,2)
    plt.suptitle(f"Time {round(dt*i,1)}")
    
    ax[0].plot(x_array,phi,label = "Potential")
        
    for my_star in stars:
        #1. PLOT FIRST
        x = my_star.x
        v = my_star.v

        ax[0].plot(x,0,".")
        ax[0].set_xlim([-L/2,L/2])
        #ax[0].set_ylim([np.min(positions),np.max(positions)])
        ax[0].legend()

        ax[1].plot(x,v,".")
        ax[1].set_xlim([-L/2,L/2])
        ax[1].set_ylim([-0.5,0.5])
        #ax[1].legend()
        
        #2. THEN EVOLVE SYSTEM
        my_star.evolve_star_dynamics(g,dt)

    #now save it as a .jpg file:
    folder = Directory + "\\" + folder_name
    filename = 'ToyModelPlot' + str(i+1).zfill(4) + '.jpg';
    plt.savefig(folder + "\\" + filename)  #save this figure (includes both subplots)
    
    plt.close() #close plot so it doesn't overlap with the next one
    time += dt
    i += 1

video_name = "ManyParticles_SHO_video.mp4"
animate(Directory,folder_name,video_name,dt)
# Out:
# ['ToyModelPlot0001.jpg', 'ToyModelPlot0002.jpg', 'ToyModelPlot0003.jpg', 'ToyModelPlot0004.jpg', 'ToyModelPlot0005.jpg', 'ToyModelPlot0006.jpg', 'ToyModelPlot0007.jpg', 'ToyModelPlot0008.jpg', 'ToyModelPlot0009.jpg', 'ToyModelPlot0010.jpg', 'ToyModelPlot0011.jpg', 'ToyModelPlot0012.jpg', 'ToyModelPlot0013.jpg', 'ToyModelPlot0014.jpg', 'ToyModelPlot0015.jpg', 'ToyModelPlot0016.jpg', 'ToyModelPlot0017.jpg', 'ToyModelPlot0018.jpg', 'ToyModelPlot0019.jpg', 'ToyModelPlot0020.jpg', 'ToyModelPlot0021.jpg', 'ToyModelPlot0022.jpg', 'ToyModelPlot0023.jpg', 'ToyModelPlot0024.jpg', 'ToyModelPlot0025.jpg', 'ToyModelPlot0026.jpg', 'ToyModelPlot0027.jpg', 'ToyModelPlot0028.jpg', 'ToyModelPlot0029.jpg', 'ToyModelPlot0030.jpg', 'ToyModelPlot0031.jpg', 'ToyModelPlot0032.jpg', 'ToyModelPlot0033.jpg', 'ToyModelPlot0034.jpg', 'ToyModelPlot0035.jpg', 'ToyModelPlot0036.jpg', 'ToyModelPlot0037.jpg', 'ToyModelPlot0038.jpg', 'ToyModelPlot0039.jpg', 'ToyModelPlot0040.jpg', 'ToyModelPlot0041.jpg', 'ToyModelPlot0042.jpg', 'ToyModelPlot0043.jpg', 'ToyModelPlot0044.jpg', 'ToyModelPlot0045.jpg', 'ToyModelPlot0046.jpg', 'ToyModelPlot0047.jpg', 'ToyModelPlot0048.jpg', 'ToyModelPlot0049.jpg', 'ToyModelPlot0050.jpg', 'ToyModelPlot0051.jpg', 'ToyModelPlot0052.jpg', 'ToyModelPlot0053.jpg', 'ToyModelPlot0054.jpg', 'ToyModelPlot0055.jpg', 'ToyModelPlot0056.jpg', 'ToyModelPlot0057.jpg', 'ToyModelPlot0058.jpg', 'ToyModelPlot0059.jpg', 'ToyModelPlot0060.jpg', 'ToyModelPlot0061.jpg', 'ToyModelPlot0062.jpg', 'ToyModelPlot0063.jpg', 'ToyModelPlot0064.jpg', 'ToyModelPlot0065.jpg', 'ToyModelPlot0066.jpg', 'ToyModelPlot0067.jpg', 'ToyModelPlot0068.jpg', 'ToyModelPlot0069.jpg', 'ToyModelPlot0070.jpg', 'ToyModelPlot0071.jpg', 'ToyModelPlot0072.jpg', 'ToyModelPlot0073.jpg', 'ToyModelPlot0074.jpg', 'ToyModelPlot0075.jpg', 'ToyModelPlot0076.jpg', 'ToyModelPlot0077.jpg', 'ToyModelPlot0078.jpg', 'ToyModelPlot0079.jpg', 'ToyModelPlot0080.jpg', 'ToyModelPlot0081.jpg', 'ToyModelPlot0082.jpg', 'ToyModelPlot0083.jpg', 'ToyModelPlot0084.jpg', 'ToyModelPlot0085.jpg', 'ToyModelPlot0086.jpg', 'ToyModelPlot0087.jpg', 'ToyModelPlot0088.jpg', 'ToyModelPlot0089.jpg', 'ToyModelPlot0090.jpg', 'ToyModelPlot0091.jpg', 'ToyModelPlot0092.jpg', 'ToyModelPlot0093.jpg', 'ToyModelPlot0094.jpg', 'ToyModelPlot0095.jpg', 'ToyModelPlot0096.jpg', 'ToyModelPlot0097.jpg', 'ToyModelPlot0098.jpg', 'ToyModelPlot0099.jpg', 'ToyModelPlot0100.jpg', 'ToyModelPlot0101.jpg', 'ToyModelPlot0102.jpg', 'ToyModelPlot0103.jpg', 'ToyModelPlot0104.jpg', 'ToyModelPlot0105.jpg', 'ToyModelPlot0106.jpg', 'ToyModelPlot0107.jpg', 'ToyModelPlot0108.jpg', 'ToyModelPlot0109.jpg', 'ToyModelPlot0110.jpg', 'ToyModelPlot0111.jpg', 'ToyModelPlot0112.jpg', 'ToyModelPlot0113.jpg', 'ToyModelPlot0114.jpg', 'ToyModelPlot0115.jpg', 'ToyModelPlot0116.jpg', 'ToyModelPlot0117.jpg', 'ToyModelPlot0118.jpg', 'ToyModelPlot0119.jpg', 'ToyModelPlot0120.jpg', 'ToyModelPlot0121.jpg', 'ToyModelPlot0122.jpg', 'ToyModelPlot0123.jpg', 'ToyModelPlot0124.jpg', 'ToyModelPlot0125.jpg', 'ToyModelPlot0126.jpg', 'ToyModelPlot0127.jpg', 'ToyModelPlot0128.jpg', 'ToyModelPlot0129.jpg', 'ToyModelPlot0130.jpg', 'ToyModelPlot0131.jpg', 'ToyModelPlot0132.jpg', 'ToyModelPlot0133.jpg', 'ToyModelPlot0134.jpg', 'ToyModelPlot0135.jpg', 'ToyModelPlot0136.jpg', 'ToyModelPlot0137.jpg', 'ToyModelPlot0138.jpg', 'ToyModelPlot0139.jpg', 'ToyModelPlot0140.jpg', 'ToyModelPlot0141.jpg', 'ToyModelPlot0142.jpg', 'ToyModelPlot0143.jpg', 'ToyModelPlot0144.jpg', 'ToyModelPlot0145.jpg', 'ToyModelPlot0146.jpg', 'ToyModelPlot0147.jpg', 'ToyModelPlot0148.jpg', 'ToyModelPlot0149.jpg', 'ToyModelPlot0150.jpg', 'ToyModelPlot0151.jpg', 'ToyModelPlot0152.jpg', 'ToyModelPlot0153.jpg', 'ToyModelPlot0154.jpg', 'ToyModelPlot0155.jpg', 'ToyModelPlot0156.jpg', 'ToyModelPlot0157.jpg', 'ToyModelPlot0158.jpg', 'ToyModelPlot0159.jpg', 'ToyModelPlot0160.jpg', 'ToyModelPlot0161.jpg', 'ToyModelPlot0162.jpg', 'ToyModelPlot0163.jpg', 'ToyModelPlot0164.jpg', 'ToyModelPlot0165.jpg', 'ToyModelPlot0166.jpg', 'ToyModelPlot01 ...

# %% [markdown]
# ## Anharmonic Potential

# %%
N = 10**3
L = 10
x = np.linspace(-L/2,L/2,N)
dx = L/(N-1)

bin_counts = np.array([0 for i in range(N-1)])

Num_stars = 100
m = 1 #mass of each star

#Set initial distribution on grid
c = 0 #center at zero
std = 1 #standard deviation of 1
x_0 = np.random.normal(c,std,Num_stars) #initial positions sampled from normal distribution
stars = [star(i,m,x_0[i],0) for i in range(len(x_0))] #create list of normally distributed stars, zero initial speed

#Set a fixed potential
a=10
b = 0.005
phi = x_array**2 / (2*a) + b*x_array**4#np.zeros_like(x) # 

#can analytically find the acceleration:
def g(x):
    return -( (x/a)+4*b*x**3 ) /m

folder_name = "ManyParticles_Anharmonic_Images"
os.chdir(Directory + "\\" + folder_name)

dt = 0.1
t_stop = 20
time = 0
i = 0 #counter, for saving images
while time <= t_stop:
    fig,ax = plt.subplots(1,2)
    plt.suptitle(f"Time {round(dt*i,1)}")
    
    ax[0].plot(x_array,phi,label = "Potential")
        
    for my_star in stars:
        #1. PLOT FIRST
        x = my_star.x
        v = my_star.v

        ax[0].plot(x,0,".")
        ax[0].set_xlim([-L/2,L/2])
        #ax[0].set_ylim([np.min(positions),np.max(positions)])
        ax[0].legend()

        ax[1].plot(x,v,".")
        ax[1].set_xlim([-L/2,L/2])
        ax[1].set_ylim([-1,1])
        #ax[1].legend()
        
        #2. THEN EVOLVE SYSTEM
        my_star.evolve_star_dynamics(g,dt)

    #now save it as a .jpg file:
    folder = Directory + "\\" + folder_name
    filename = 'ToyModelPlot' + str(i+1).zfill(4) + '.jpg';
    plt.savefig(folder + "\\" + filename)  #save this figure (includes both subplots)
    
    plt.close() #close plot so it doesn't overlap with the next one
    time += dt
    i += 1

video_name = "ManyParticles_Anharmonic_video.mp4"
animate(Directory,folder_name,video_name,dt)
# Out:
# ['ToyModelPlot0001.jpg', 'ToyModelPlot0002.jpg', 'ToyModelPlot0003.jpg', 'ToyModelPlot0004.jpg', 'ToyModelPlot0005.jpg', 'ToyModelPlot0006.jpg', 'ToyModelPlot0007.jpg', 'ToyModelPlot0008.jpg', 'ToyModelPlot0009.jpg', 'ToyModelPlot0010.jpg', 'ToyModelPlot0011.jpg', 'ToyModelPlot0012.jpg', 'ToyModelPlot0013.jpg', 'ToyModelPlot0014.jpg', 'ToyModelPlot0015.jpg', 'ToyModelPlot0016.jpg', 'ToyModelPlot0017.jpg', 'ToyModelPlot0018.jpg', 'ToyModelPlot0019.jpg', 'ToyModelPlot0020.jpg', 'ToyModelPlot0021.jpg', 'ToyModelPlot0022.jpg', 'ToyModelPlot0023.jpg', 'ToyModelPlot0024.jpg', 'ToyModelPlot0025.jpg', 'ToyModelPlot0026.jpg', 'ToyModelPlot0027.jpg', 'ToyModelPlot0028.jpg', 'ToyModelPlot0029.jpg', 'ToyModelPlot0030.jpg', 'ToyModelPlot0031.jpg', 'ToyModelPlot0032.jpg', 'ToyModelPlot0033.jpg', 'ToyModelPlot0034.jpg', 'ToyModelPlot0035.jpg', 'ToyModelPlot0036.jpg', 'ToyModelPlot0037.jpg', 'ToyModelPlot0038.jpg', 'ToyModelPlot0039.jpg', 'ToyModelPlot0040.jpg', 'ToyModelPlot0041.jpg', 'ToyModelPlot0042.jpg', 'ToyModelPlot0043.jpg', 'ToyModelPlot0044.jpg', 'ToyModelPlot0045.jpg', 'ToyModelPlot0046.jpg', 'ToyModelPlot0047.jpg', 'ToyModelPlot0048.jpg', 'ToyModelPlot0049.jpg', 'ToyModelPlot0050.jpg', 'ToyModelPlot0051.jpg', 'ToyModelPlot0052.jpg', 'ToyModelPlot0053.jpg', 'ToyModelPlot0054.jpg', 'ToyModelPlot0055.jpg', 'ToyModelPlot0056.jpg', 'ToyModelPlot0057.jpg', 'ToyModelPlot0058.jpg', 'ToyModelPlot0059.jpg', 'ToyModelPlot0060.jpg', 'ToyModelPlot0061.jpg', 'ToyModelPlot0062.jpg', 'ToyModelPlot0063.jpg', 'ToyModelPlot0064.jpg', 'ToyModelPlot0065.jpg', 'ToyModelPlot0066.jpg', 'ToyModelPlot0067.jpg', 'ToyModelPlot0068.jpg', 'ToyModelPlot0069.jpg', 'ToyModelPlot0070.jpg', 'ToyModelPlot0071.jpg', 'ToyModelPlot0072.jpg', 'ToyModelPlot0073.jpg', 'ToyModelPlot0074.jpg', 'ToyModelPlot0075.jpg', 'ToyModelPlot0076.jpg', 'ToyModelPlot0077.jpg', 'ToyModelPlot0078.jpg', 'ToyModelPlot0079.jpg', 'ToyModelPlot0080.jpg', 'ToyModelPlot0081.jpg', 'ToyModelPlot0082.jpg', 'ToyModelPlot0083.jpg', 'ToyModelPlot0084.jpg', 'ToyModelPlot0085.jpg', 'ToyModelPlot0086.jpg', 'ToyModelPlot0087.jpg', 'ToyModelPlot0088.jpg', 'ToyModelPlot0089.jpg', 'ToyModelPlot0090.jpg', 'ToyModelPlot0091.jpg', 'ToyModelPlot0092.jpg', 'ToyModelPlot0093.jpg', 'ToyModelPlot0094.jpg', 'ToyModelPlot0095.jpg', 'ToyModelPlot0096.jpg', 'ToyModelPlot0097.jpg', 'ToyModelPlot0098.jpg', 'ToyModelPlot0099.jpg', 'ToyModelPlot0100.jpg', 'ToyModelPlot0101.jpg', 'ToyModelPlot0102.jpg', 'ToyModelPlot0103.jpg', 'ToyModelPlot0104.jpg', 'ToyModelPlot0105.jpg', 'ToyModelPlot0106.jpg', 'ToyModelPlot0107.jpg', 'ToyModelPlot0108.jpg', 'ToyModelPlot0109.jpg', 'ToyModelPlot0110.jpg', 'ToyModelPlot0111.jpg', 'ToyModelPlot0112.jpg', 'ToyModelPlot0113.jpg', 'ToyModelPlot0114.jpg', 'ToyModelPlot0115.jpg', 'ToyModelPlot0116.jpg', 'ToyModelPlot0117.jpg', 'ToyModelPlot0118.jpg', 'ToyModelPlot0119.jpg', 'ToyModelPlot0120.jpg', 'ToyModelPlot0121.jpg', 'ToyModelPlot0122.jpg', 'ToyModelPlot0123.jpg', 'ToyModelPlot0124.jpg', 'ToyModelPlot0125.jpg', 'ToyModelPlot0126.jpg', 'ToyModelPlot0127.jpg', 'ToyModelPlot0128.jpg', 'ToyModelPlot0129.jpg', 'ToyModelPlot0130.jpg', 'ToyModelPlot0131.jpg', 'ToyModelPlot0132.jpg', 'ToyModelPlot0133.jpg', 'ToyModelPlot0134.jpg', 'ToyModelPlot0135.jpg', 'ToyModelPlot0136.jpg', 'ToyModelPlot0137.jpg', 'ToyModelPlot0138.jpg', 'ToyModelPlot0139.jpg', 'ToyModelPlot0140.jpg', 'ToyModelPlot0141.jpg', 'ToyModelPlot0142.jpg', 'ToyModelPlot0143.jpg', 'ToyModelPlot0144.jpg', 'ToyModelPlot0145.jpg', 'ToyModelPlot0146.jpg', 'ToyModelPlot0147.jpg', 'ToyModelPlot0148.jpg', 'ToyModelPlot0149.jpg', 'ToyModelPlot0150.jpg', 'ToyModelPlot0151.jpg', 'ToyModelPlot0152.jpg', 'ToyModelPlot0153.jpg', 'ToyModelPlot0154.jpg', 'ToyModelPlot0155.jpg', 'ToyModelPlot0156.jpg', 'ToyModelPlot0157.jpg', 'ToyModelPlot0158.jpg', 'ToyModelPlot0159.jpg', 'ToyModelPlot0160.jpg', 'ToyModelPlot0161.jpg', 'ToyModelPlot0162.jpg', 'ToyModelPlot0163.jpg', 'ToyModelPlot0164.jpg', 'ToyModelPlot0165.jpg', 'ToyModelPlot0166.jpg', 'ToyModelPlot01 ...

# %% [markdown]
# ## Anharmonic Potential with Particles Offset from Center

# %%
N = 10**3
L = 10
x = np.linspace(-L/2,L/2,N)
dx = L/(N-1)

bin_counts = np.array([0 for i in range(N-1)])

Num_stars = 100
m = 1 #mass of each star

#Set initial distribution on grid
c = -L/4 #center at zero
std = 1 #standard deviation of 1
x_0 = np.random.normal(c,std,Num_stars) #initial positions sampled from normal distribution
stars = [star(i,m,x_0[i],0) for i in range(len(x_0))] #create list of normally distributed stars, zero initial speed

#Set a fixed potential
a=10
b = 0.005
phi = x_array**2 / (2*a) + b*x_array**4#np.zeros_like(x) # 

#can analytically find the acceleration:
def g(x):
    return -( (x/a)+4*b*x**3 ) /m

folder_name = "ManyParticles_Anharmonic_Offset_Images"
os.chdir(Directory + "\\" + folder_name)

dt = 0.1
t_stop = 20
time = 0
i = 0 #counter, for saving images
while time <= t_stop:
    fig,ax = plt.subplots(1,2)
    plt.suptitle(f"Time {round(dt*i,1)}")
    
    ax[0].plot(x_array,phi,label = "Potential")
        
    for my_star in stars:
        #1. PLOT FIRST
        x = my_star.x
        v = my_star.v

        ax[0].plot(x,0,".")
        ax[0].set_xlim([-L/2,L/2])
        #ax[0].set_ylim([np.min(positions),np.max(positions)])
        ax[0].legend()

        ax[1].plot(x,v,".")
        ax[1].set_xlim([-L/2,L/2])
        ax[1].set_ylim([-5,5])
        #ax[1].legend()
        
        #2. THEN EVOLVE SYSTEM
        my_star.evolve_star_dynamics(g,dt)

    #now save it as a .jpg file:
    folder = Directory + "\\" + folder_name
    filename = 'ToyModelPlot' + str(i+1).zfill(4) + '.jpg';
    plt.savefig(folder + "\\" + filename)  #save this figure (includes both subplots)
    
    plt.close() #close plot so it doesn't overlap with the next one
    time += dt
    i += 1

video_name = "ManyParticles_Anharmonic_Offset_video.mp4"
animate(Directory,folder_name,video_name,dt)
# Out:
# ['ToyModelPlot0001.jpg', 'ToyModelPlot0002.jpg', 'ToyModelPlot0003.jpg', 'ToyModelPlot0004.jpg', 'ToyModelPlot0005.jpg', 'ToyModelPlot0006.jpg', 'ToyModelPlot0007.jpg', 'ToyModelPlot0008.jpg', 'ToyModelPlot0009.jpg', 'ToyModelPlot0010.jpg', 'ToyModelPlot0011.jpg', 'ToyModelPlot0012.jpg', 'ToyModelPlot0013.jpg', 'ToyModelPlot0014.jpg', 'ToyModelPlot0015.jpg', 'ToyModelPlot0016.jpg', 'ToyModelPlot0017.jpg', 'ToyModelPlot0018.jpg', 'ToyModelPlot0019.jpg', 'ToyModelPlot0020.jpg', 'ToyModelPlot0021.jpg', 'ToyModelPlot0022.jpg', 'ToyModelPlot0023.jpg', 'ToyModelPlot0024.jpg', 'ToyModelPlot0025.jpg', 'ToyModelPlot0026.jpg', 'ToyModelPlot0027.jpg', 'ToyModelPlot0028.jpg', 'ToyModelPlot0029.jpg', 'ToyModelPlot0030.jpg', 'ToyModelPlot0031.jpg', 'ToyModelPlot0032.jpg', 'ToyModelPlot0033.jpg', 'ToyModelPlot0034.jpg', 'ToyModelPlot0035.jpg', 'ToyModelPlot0036.jpg', 'ToyModelPlot0037.jpg', 'ToyModelPlot0038.jpg', 'ToyModelPlot0039.jpg', 'ToyModelPlot0040.jpg', 'ToyModelPlot0041.jpg', 'ToyModelPlot0042.jpg', 'ToyModelPlot0043.jpg', 'ToyModelPlot0044.jpg', 'ToyModelPlot0045.jpg', 'ToyModelPlot0046.jpg', 'ToyModelPlot0047.jpg', 'ToyModelPlot0048.jpg', 'ToyModelPlot0049.jpg', 'ToyModelPlot0050.jpg', 'ToyModelPlot0051.jpg', 'ToyModelPlot0052.jpg', 'ToyModelPlot0053.jpg', 'ToyModelPlot0054.jpg', 'ToyModelPlot0055.jpg', 'ToyModelPlot0056.jpg', 'ToyModelPlot0057.jpg', 'ToyModelPlot0058.jpg', 'ToyModelPlot0059.jpg', 'ToyModelPlot0060.jpg', 'ToyModelPlot0061.jpg', 'ToyModelPlot0062.jpg', 'ToyModelPlot0063.jpg', 'ToyModelPlot0064.jpg', 'ToyModelPlot0065.jpg', 'ToyModelPlot0066.jpg', 'ToyModelPlot0067.jpg', 'ToyModelPlot0068.jpg', 'ToyModelPlot0069.jpg', 'ToyModelPlot0070.jpg', 'ToyModelPlot0071.jpg', 'ToyModelPlot0072.jpg', 'ToyModelPlot0073.jpg', 'ToyModelPlot0074.jpg', 'ToyModelPlot0075.jpg', 'ToyModelPlot0076.jpg', 'ToyModelPlot0077.jpg', 'ToyModelPlot0078.jpg', 'ToyModelPlot0079.jpg', 'ToyModelPlot0080.jpg', 'ToyModelPlot0081.jpg', 'ToyModelPlot0082.jpg', 'ToyModelPlot0083.jpg', 'ToyModelPlot0084.jpg', 'ToyModelPlot0085.jpg', 'ToyModelPlot0086.jpg', 'ToyModelPlot0087.jpg', 'ToyModelPlot0088.jpg', 'ToyModelPlot0089.jpg', 'ToyModelPlot0090.jpg', 'ToyModelPlot0091.jpg', 'ToyModelPlot0092.jpg', 'ToyModelPlot0093.jpg', 'ToyModelPlot0094.jpg', 'ToyModelPlot0095.jpg', 'ToyModelPlot0096.jpg', 'ToyModelPlot0097.jpg', 'ToyModelPlot0098.jpg', 'ToyModelPlot0099.jpg', 'ToyModelPlot0100.jpg', 'ToyModelPlot0101.jpg', 'ToyModelPlot0102.jpg', 'ToyModelPlot0103.jpg', 'ToyModelPlot0104.jpg', 'ToyModelPlot0105.jpg', 'ToyModelPlot0106.jpg', 'ToyModelPlot0107.jpg', 'ToyModelPlot0108.jpg', 'ToyModelPlot0109.jpg', 'ToyModelPlot0110.jpg', 'ToyModelPlot0111.jpg', 'ToyModelPlot0112.jpg', 'ToyModelPlot0113.jpg', 'ToyModelPlot0114.jpg', 'ToyModelPlot0115.jpg', 'ToyModelPlot0116.jpg', 'ToyModelPlot0117.jpg', 'ToyModelPlot0118.jpg', 'ToyModelPlot0119.jpg', 'ToyModelPlot0120.jpg', 'ToyModelPlot0121.jpg', 'ToyModelPlot0122.jpg', 'ToyModelPlot0123.jpg', 'ToyModelPlot0124.jpg', 'ToyModelPlot0125.jpg', 'ToyModelPlot0126.jpg', 'ToyModelPlot0127.jpg', 'ToyModelPlot0128.jpg', 'ToyModelPlot0129.jpg', 'ToyModelPlot0130.jpg', 'ToyModelPlot0131.jpg', 'ToyModelPlot0132.jpg', 'ToyModelPlot0133.jpg', 'ToyModelPlot0134.jpg', 'ToyModelPlot0135.jpg', 'ToyModelPlot0136.jpg', 'ToyModelPlot0137.jpg', 'ToyModelPlot0138.jpg', 'ToyModelPlot0139.jpg', 'ToyModelPlot0140.jpg', 'ToyModelPlot0141.jpg', 'ToyModelPlot0142.jpg', 'ToyModelPlot0143.jpg', 'ToyModelPlot0144.jpg', 'ToyModelPlot0145.jpg', 'ToyModelPlot0146.jpg', 'ToyModelPlot0147.jpg', 'ToyModelPlot0148.jpg', 'ToyModelPlot0149.jpg', 'ToyModelPlot0150.jpg', 'ToyModelPlot0151.jpg', 'ToyModelPlot0152.jpg', 'ToyModelPlot0153.jpg', 'ToyModelPlot0154.jpg', 'ToyModelPlot0155.jpg', 'ToyModelPlot0156.jpg', 'ToyModelPlot0157.jpg', 'ToyModelPlot0158.jpg', 'ToyModelPlot0159.jpg', 'ToyModelPlot0160.jpg', 'ToyModelPlot0161.jpg', 'ToyModelPlot0162.jpg', 'ToyModelPlot0163.jpg', 'ToyModelPlot0164.jpg', 'ToyModelPlot0165.jpg', 'ToyModelPlot0166.jpg', 'ToyModelPlot01 ...
