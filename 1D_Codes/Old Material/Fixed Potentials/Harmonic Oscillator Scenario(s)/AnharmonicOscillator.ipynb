# %%
#Import External Libraries
import numpy as np
import matplotlib.pyplot as plt
import os 
import cv2 
from PIL import Image 

#Import My Library
My_Module_PATH = "C:\\Users\\boris\\OneDrive - Queen's University\\Documents\\JOB_Files\\McDonald Institute Fellowship\\Research\\Coding\\1D codes"
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, My_Module_PATH)
from OneD_module import *

#Set up Directory for saving files/images/videos
# Will not rename this again
Directory = "C:\\Users\\boris\\OneDrive - Queen's University\\Documents\\JOB_Files\\McDonald Institute Fellowship\\Research\\Coding\\1D codes\\Fixed Potentials\\Harmonic Oscillator Scenario(s)"

# %%
N = 10**3
L = 20
x = np.linspace(-L/2,L/2,N)
dx = L/(N-1)
hbar = 1
m = 5

shift=0
std=1
rho_init = m*gauss(x,shift,std)
psi = np.sqrt(rho_init/m) #assuming psi_initial to be real valued and non-negative

#Set a fixed potential
a=10
b = 0.005
phi = x**2 / (2*a) + b * x**4 #np.zeros_like(x) # 

#phi = real_fourier_potential(psi,m)

#Calculate initial Density perturbation
rho = m*np.absolute(psi)**2
rho_avg = np.mean(rho)
P = rho-rho_avg

#storage space, with initial functions
P_s = np.array([P]) #initial density perturbation
psi_s = np.array([psi]) #initial wavefunction
phi_s = np.array([phi]) #initial potential [perturbation]

dt = 0.1
t_stop = 20
time = 0
while time <= t_stop:
    
    #Evolve system forward by one time-step
    psi,phi,P = time_evolve_FixedPhi(psi,phi,dx,dt,hbar,m)
    
    #Append/store new arrays
    psi_s = np.append(psi_s,[psi], axis = 0)
    P_s = np.append(P_s, [P], axis = 0)
    phi_s = np.append(phi_s,[phi], axis = 0)

    time += dt #forward on the clock

    #if math.isnan(H(psi,phi,dx,hbar,m)[0]) == True:
     #   break

# %%
folder_name = "AnharmonicOscillator_Images"
plot_save_waves(x,psi_s,phi_s,P_s,dt,Directory,folder_name)
print("Plotting Done.")

video_name = "AnharmonicOscillator_video.mp4"
animate(Directory,folder_name,video_name,dt)
# Out:
# Plotting Done.
# ['ToyModelPlot0001.jpg', 'ToyModelPlot0002.jpg', 'ToyModelPlot0003.jpg', 'ToyModelPlot0004.jpg', 'ToyModelPlot0005.jpg', 'ToyModelPlot0006.jpg', 'ToyModelPlot0007.jpg', 'ToyModelPlot0008.jpg', 'ToyModelPlot0009.jpg', 'ToyModelPlot0010.jpg', 'ToyModelPlot0011.jpg', 'ToyModelPlot0012.jpg', 'ToyModelPlot0013.jpg', 'ToyModelPlot0014.jpg', 'ToyModelPlot0015.jpg', 'ToyModelPlot0016.jpg', 'ToyModelPlot0017.jpg', 'ToyModelPlot0018.jpg', 'ToyModelPlot0019.jpg', 'ToyModelPlot0020.jpg', 'ToyModelPlot0021.jpg', 'ToyModelPlot0022.jpg', 'ToyModelPlot0023.jpg', 'ToyModelPlot0024.jpg', 'ToyModelPlot0025.jpg', 'ToyModelPlot0026.jpg', 'ToyModelPlot0027.jpg', 'ToyModelPlot0028.jpg', 'ToyModelPlot0029.jpg', 'ToyModelPlot0030.jpg', 'ToyModelPlot0031.jpg', 'ToyModelPlot0032.jpg', '
g', 'ToyModelPlot0123.jpg', 'ToyModelPlot0124.jpg', 'ToyModelPlot0125.jpg', 'ToyModelPlot0126.jpg', 'ToyModelPlot0127.jpg', 'ToyModelPlot0128.jpg', 'ToyModelPlot0129.jpg', 'ToyModelPlot0130.jpg', 'ToyModelPlot0131.jpg', 'ToyModelPlot0132.jpg', 'ToyModelPlot0133.jpg', 'ToyModelPlot0134.jpg', 'ToyModelPlot0135.jpg', 'ToyModelPlot0136.jpg', 'ToyModelPlot0137.jpg', 'ToyModelPlot0138.jpg', 'ToyModelPlot0139.jpg', 'ToyModelPlot0140.jpg', 'ToyModelPlot0141.jpg', 'ToyModelPlot0142.jpg', 'ToyModelPlot0143.jpg', 'ToyModelPlot0144.jpg', 'ToyModelPlot0145.jpg', 'ToyModelPlot0146.jpg', 'ToyModelPlot0147.jpg', 'ToyModelPlot0148.jpg', 'ToyModelPlot0149.jpg', 'ToyModelPlot0150.jpg', 'ToyModelPlot0151.jpg', 'ToyModelPlot0152.jpg', 'ToyModelPlot0153.jpg', 'ToyModelPlot0154.jpg', 'ToyModelPlot0155.jpg', 'ToyModelPlot0156.jpg', 'ToyModelPlot0157.jpg', 'ToyModelPlot0158.jpg', 'ToyModelPlot0159.jpg', 'ToyModelPlot0160.jpg', 'ToyModelPlot0161.jpg', 'ToyModelPlot0162.jpg', 'ToyModelPlot0163.jpg', 'ToyModelPlot0164.jpg', 'ToyModelPlot0165.jpg', 'ToyModelPlot0166.jpg', 'ToyModelPlot01 ...

# %%
from matplotlib.colors import Normalize

k = 2*np.pi*np.fft.fftfreq(len(x),dx)
x_min, x_max = np.min(x), np.max(x)
k_min, k_max = np.min(k), np.max(k)

y_min,y_max = -10,10

for i in range(0,200,25):
    F = Husimi_phase(psi_s[i],x,dx,hbar)
    #fig,ax = plt.subplots(1,1)
    plt.figure(figsize = (10,5))
    plt.imshow(F,extent = (x_min,x_max,k_min,k_max),cmap = cm.hot, aspect = x_max/y_max)
    plt.xlim([x_min,x_max])
    plt.ylim([y_min,y_max])
    plt.colorbar()
    plt.show()

# %%
folder_name = "AnharmonicOscillator_Phase_Images"
frame_spacing = 1
max_F = 2*10**5
y_max = 10
generate_phase_plots(psi_s,x,dx,hbar,y_max,max_F,frame_spacing, Directory, folder_name)

video_name = "AnharmonicOscillator_Phase_video.mp4"
generate_phase_video(Directory,folder_name,video_name,dt,frame_spacing)
# Out:
# 0  Done
# 1  Done
# 2  Done
# 3  Done
# 4  Done
# 5  Done
# 6  Done
# 7  Done
# 8  Done
# 9  Done
# 10  Done
# 11  Done
# 12  Done
# 13  Done
# 14  Done
# 15  Done
# 16  Done
# 17  Done
# 18  Done
# 19  Done
# 20  Done
# 21  Done
# 22  Done
# 23  Done
# 24  Done
# 25  Done
# 26  Done
# 27  Done
# 28  Done
# 29  Done
# 30  Done
# 31  Done
# 32  Done
# 33  Done
# 34  Done
# 35  Done
# 36  Done
# 37  Done
# 38  Done
# 39  Done
# 40  Done
# 41  Done
# 42  Done
# 43  Done
# 44  Done
# 45  Done
# 46  Done
# 47  Done
# 48  Done
# 49  Done
# 50  Done
# 51  Done
# 52  Done
# 53  Done
# 54  Done
# 55  Done
# 56  Done
# 57  Done
# 58  Done
# 59  Done
# 60  Done
# 61  Done
# 62  Done
# 63  Done
# 64  Done
# 65  Done
# 66  Done
# 67  Done
# 68  Done
# 69  Done
# 70  Done
# 71  Done
# 72  Done
# 73  Done
# 74  Done
# 75  Done
# 76  Done
# 77  Done
# 78  Done
# 79  Done
# 80  Done
# 81  Done
# 82  Done
# 83  Done
# 84  Done
# 85  Done
# 86  Done
# 87  Done
# 88  Done
# 89  Done
# 90  Done
# 91  Done
# 92  Done
# 93  Done
# 94  Done
# 95  Done
# 96  Done
# 97  Done
# 98  Done
# 99  Done
# 100  Done
# 101  Done
# 102  Done
# 103  Done
# 104  Done
# 105  Done
# 106  Done
# 107  Done
# 108  Done
# 109  Done
# 110  Done
# 111  Done
# 112  Done
# 113  Done
# 114  Done
# 115  Done
# 116  Done
# 117  Done
# 118  Done
# 119  Done
# 120  Done
# 121  Done
# 122  Done
# 123  Done
# 124  Done
# 125  Done
# 126  Done
# 127  Done
# 128  Done
# 129  Done
# 130  Done
# 131  Done
# 132  Done
# 133  Done
# 134  Done
# 135  Done
# 136  Done
# 137  Done
# 138  Done
# 139  Done
# 140  Done
# 141  Done
# 142  Done
# 143  Done
# 144  Done
# 145  Done
# 146  Done
# 147  Done
# 148  Done
# 149  Done
# 150  Done
# 151  Done
# 152  Done
# 153  Done
# 154  Done
# 155  Done
# 156  Done
# 157  Done
# 158  Done
# 159  Done
# 160  Done
# 161  Done
# 162  Done
# 163  Done
# 164  Done
# 165  Done
# 166  Done
# 167  Done
# 168  Done
# 169  Done
# 170  Done
# 171  Done
# 172  Done
# 173  Done
# 174  Done
# 175  Done
# 176  Done
# 177  Done
# 178  Done
# 179  Done
# 180  Done
# 181  Done
# 182  Done
# 183  Done
# 184  Done
# 185  Done
# 186  Done
# 187  Done
# 188  Done
# 189  Done
# 190  Done
# 191  Done
# 192  Done
# 193  Done
# 194  Done
# 195  Done
# 196  Done
# 197  Done
# 198  Done
# 199  Done
# 200  Done
# ['ToyModelPlot0001.jpg', 'ToyModelPlot0002.jpg', 'ToyModelPlot0003.jpg', 'ToyModelPlot0004.jpg', 'ToyModelPlot0005.jpg', 'ToyModelPlot0006.jpg', 'ToyModelPlot0007.jpg', 'ToyModelPlot0008.jpg', 'ToyModelPlot0009.jpg', 'ToyModelPlot0010.jpg', 'ToyModelPlot0011.jpg', 'ToyModelPlot0012.jpg', 'ToyModelPlot0013.jpg', 'ToyModelPlot0014.jpg', 'ToyModelPlot0015.jpg', 'ToyModelPlot0016.jpg', 'ToyModelPlot0017.jpg', 'ToyModelPlot0018.jpg', 'ToyModelPlot0019.jpg', 'ToyModelPlot0020.jpg', 'ToyModelPlot0021.jpg', 'ToyModelPlot0022.jpg', 'ToyModelPlot0023.jpg', 'ToyModelPlot0024.jpg', 'ToyModelPlot0025.jpg', 
pg', 'ToyModelPlot0116.jpg', 'ToyModelPlot0117.jpg', 'ToyModelPlot0118.jpg', 'ToyModelPlot0119.jpg', 'ToyModelPlot0120.jpg', 'ToyModelPlot0121.jpg', 'ToyModelPlot0122.jpg', 'ToyModelPlot0123.jpg', 'ToyModelPlot0124.jpg', 'ToyModelPlot0125.jpg', 'ToyModelPlot0126.jpg', 'ToyModelPlot0127.jpg', 'ToyModelPlot0128.jpg', 'ToyModelPlot0129.jpg', 'ToyModelPlot0130.jpg', 'ToyModelPlot0131.jpg', 'ToyModelPlot0132.jpg', 'ToyModelPlot0133.jpg', 'ToyModelPlot0134.jpg', 'ToyModelPlot0135.jpg', 'ToyModelPlot0136.jpg', 'ToyModelPlot0137.jpg', 'ToyModelPlot0138.jpg', 'ToyModelPlot0139.jpg', 'ToyModelPlot0140.jpg', 'ToyModelPlot0141.jpg', 'ToyModelPlot0142.jpg', 'ToyModelPlot0143.jpg', 'ToyModelPlot0144.jpg', 'ToyModelPlot0145.jpg', 'ToyModelPlot0146.jpg', 'ToyModelPlot0147.jpg', 'ToyModelPlot0148.jpg', 'ToyModelPlot0149.jpg', 'ToyModelPlot0150.jpg', 'ToyModelPlot0151.jpg', 'ToyModelPlot0152.jpg', 'ToyModelPlot0153.jpg', 'ToyModelPlot0154.jpg', 'ToyModelPlot0155.jpg', 'ToyModelPlot0156.jpg', 'ToyModelPlot0157.jpg', 'ToyModelPlot0158.jpg', 'ToyModelPlot0159.jpg', 'ToyModelPlot0160.jpg', 'ToyModelPlot0161.jpg', 'ToyModelPlot0162.jpg', 'ToyModelPlot0163.jpg', 'ToyModelPlot0164.jpg', 'ToyModelPlot0165.jpg', 'ToyModelPlot0166.jpg', 'ToyModelPlot01 ...

# %% [markdown]
# ## Offset Initial Condition:

# %%
N = 10**3
L = 20
x = np.linspace(-L/2,L/2,N)
dx = L/(N-1)
hbar = 1
m = 5

shift=-L/4
std=1
rho_init = m*gauss(x,shift,std)
psi = np.sqrt(rho_init/m) #assuming psi_initial to be real valued and non-negative

#Set a fixed potential
a=10
b = 0.005
phi = x**2 / (2*a) + b * x**4 #np.zeros_like(x) # 

#phi = real_fourier_potential(psi,m)

#Calculate initial Density perturbation
rho = m*np.absolute(psi)**2
rho_avg = np.mean(rho)
P = rho-rho_avg

#storage space, with initial functions
P_s = np.array([P]) #initial density perturbation
psi_s = np.array([psi]) #initial wavefunction
phi_s = np.array([phi]) #initial potential [perturbation]

dt = 0.1
t_stop = 20
time = 0
while time <= t_stop:
    
    #Evolve system forward by one time-step
    psi,phi,P = time_evolve_FixedPhi(psi,phi,dx,dt,hbar,m)
    
    #Append/store new arrays
    psi_s = np.append(psi_s,[psi], axis = 0)
    P_s = np.append(P_s, [P], axis = 0)
    phi_s = np.append(phi_s,[phi], axis = 0)

    time += dt #forward on the clock

    #if math.isnan(H(psi,phi,dx,hbar,m)[0]) == True:
     #   break

# %%
folder_name = "AnharmonicOscillator_Offset_Images"
plot_save_waves(x,psi_s,phi_s,P_s,dt,Directory,folder_name)
085.jpg', 'ToyModelPlot0086.jpg', 'ToyModelPlot0087.jpg', 'ToyModelPlot0088.jpg', 'ToyModelPlot0089.jpg', 'ToyModelPlot0090.jpg', 'ToyModelPlot0091.jpg', 'ToyModelPlot0092.jpg', 'ToyModelPlot0093.jpg', 'ToyModelPlot0094.jpg', 'ToyModelPlot0095.jpg', 'ToyModelPlot0096.jpg', 'ToyModelPlot0097.jpg', 'ToyModelPlot0098.jpg', 'ToyModelPlot0099.jpg', 'ToyModelPlot0100.jpg', 'ToyModelPlot0101.jpg', 'ToyModelPlot0102.jpg', 'ToyModelPlot0103.jpg', 'ToyModelPlot0104.jpg', 'ToyModelPlot0105.jpg', 'ToyModelPlot0106.jpg', 'ToyModelPlot0107.jpg', 'ToyModelPlot0108.jpg', 'ToyModelPlot0109.jpg', 'ToyModelPlot0110.jpg', 'ToyModelPlot0111.jpg', 'ToyModelPlot0112.jpg', 'ToyModelPlot0113.jpg', 'ToyModelPlot0114.jpg', 'ToyModelPlot0115.jpg', 'ToyModelPlot0116.jpg', 'ToyModelPlot0117.jpg', 'ToyModelPlot0118.jpg', 'ToyModelPlot0119.jpg', 'ToyModelPlot0120.jpg', 'ToyModelPlot0121.jpg', 'ToyModelPlot0122.jpg', 'ToyModelPlot0123.jpg', 'ToyModelPlot0124.jpg', 'ToyModelPlot0125.jpg', 'ToyModelPlot0126.jpg', 'ToyModelPlot0127.jpg', 'ToyModelPlot0128.jpg', 'ToyModelPlot0129.jpg', 'ToyModelPlot0130.jpg', 'ToyModelPlot0131.jpg', 'ToyModelPlot0132.jpg', 'ToyModelPlot0133.jpg', 'ToyModelPlot0134.jpg', 'ToyModelPlot0135.jpg', 'ToyModelPlot0136.jpg', 'ToyModelPlot0137.jpg', 'ToyModelPlot0138.jpg', 'ToyModelPlot0139.jpg', 'ToyModelPlot0140.jpg', 'ToyModelPlot0141.jpg', 'ToyModelPlot0142.jpg', 'ToyModelPlot0143.jpg', 'ToyModelPlot0144.jpg', 'ToyModelPlot0145.jpg', 'ToyModelPlot0146.jpg', 'ToyModelPlot0147.jpg', 'ToyModelPlot0148.jpg', 'ToyModelPlot0149.jpg', 'ToyModelPlot0150.jpg', 'ToyModelPlot0151.jpg', 'ToyModelPlot0152.jpg', 'ToyModelPlot0153.jpg', 'ToyModelPlot0154.jpg', 'ToyModelPlot0155.jpg', 'ToyModelPlot0156.jpg', 'ToyModelPlot0157.jpg', 'ToyModelPlot0158.jpg', 'ToyModelPlot0159.jpg', 'ToyModelPlot0160.jpg', 'ToyModelPlot0161.jpg', 'ToyModelPlot0162.jpg', 'ToyModelPlot0163.jpg', 'ToyModelPlot0164.jpg', 'ToyModelPlot0165.jpg', 'ToyModelPlot0166.jpg', 'ToyModelPlot01 ...

# %%
from matplotlib.colors import Normalize

k = 2*np.pi*np.fft.fftfreq(len(x),dx)
x_min, x_max = np.min(x), np.max(x)
k_min, k_max = np.min(k), np.max(k)

y_min,y_max = -40,40

for i in range(0,200,25):
    F = Husimi_phase(psi_s[i],x,dx,hbar)
    #fig,ax = plt.subplots(1,1)
    plt.figure(figsize = (10,5))
    plt.imshow(F,extent = (x_min,x_max,k_min,k_max),cmap = cm.hot, aspect = x_max/y_max)
    plt.xlim([x_min,x_max])
    plt.ylim([y_min,y_max])
    plt.colorbar()
    plt.show()

# %%
folder_name = "AnharmonicOscillator_Offset_Phase_Images"
frame_spacing = 1
max_F = 5*10**4
y_max = 40
generate_phase_plots(psi_s,x,dx,hbar,y_max,max_F,frame_spacing, Directory, folder_name)

video_name = "AnharmonicOscillator_Offset_Phase_video.mp4"
generate_phase_video(Directory,folder_name,video_name,dt,frame_spacing)
# Out:
# 0  Done
# 1  Done
# 2  Done
# 3  Done
# 4  Done
# 5  Done
# 6  Done
# 7  Done
# 8  Done
# 9  Done
# 10  Done
# 11  Done
# 12  Done
# 13  Done
# 14  Done
# 15  Done
# 16  Done
# 17  Done
# 18  Done
# 19  Done
# 20  Done
# 21  Done
# 22  Done
# 23  Done
# 24  Done
# 25  Done
# 26  Done
# 27  Done
# 28  Done
# 29  Done
# 30  Done
# 31  Done
# 32  Done
# 33  Done
# 34  Done
# 35  Done
# 36  Done
# 37  Done
# 38  Done
# 39  Done
# 40  Done
# 41  Done
# 42  Done
# 43  Done
# 44  Done
# 45  Done
# 46  Done
# 47  Done
# 48  Done
# 49  Done
# 50  Done
# 51  Done
# 52  Done
# 53  Done
# 54  Done
# 55  Done
# 56  Done
# 57  Done
# 58  Done
# 59  Done
# 60  Done
# 61  Done
# 62  Done
# 63  Done
# 64  Done
# 65  Done
# 66  Done
# 67  Done
# 68  Done
# 69  Done
# 70  Done
# 71  Done
# 72  Done
# 73  Done
# 74  Done
# 75  Done
# 76  Done
# 77  Done
# 78  Done
# 79  Done
# 80  Done
# 81  Done
# 82  Done
# 83  Done
# 84  Done
# 85  Done
# 86  Done
# 87  Done
# 88  Done
# 89  Done
# 90  Done
# 91  Done
# 92  Done
# 93  Done
# 94  Done
# 95  Done
# 96  Done
# 97  Done
# 98  Done
# 99  Done
# 100  Done
# 101  Done
# 102  Done
# 103  Done
# 104  Done
# 105  Done
# 106  Done
# 107  Done
# 108  Done
# 109  Done
# 110  Done
# 111  Done
# 112  Done
# 113  Done
# 114  Done
# 115  Done
# 116  Done
# 117  Done
# 118  Done
# 119  Done
# 120  Done
# 121  Done
# 122  Done
# 123  Done
# 124  Done
# 125  Done
# 126  Done
# 127  Done
# 128  Done
# 129  Done
# 130  Done
# 131  Done
# 132  Done
# 133  Done
# 134  Done
# 135  Done
# 136  Done
# 137  Done
# 138  Done
# 139  Done
# 140  Done
# 141  Done
# 142  Done
# 143  Done
# 144  Done
# 145  Done
# 146  Done
# 147  Done
# 148  Done
# 149  Done
# 150  Done
# 151  Done
# 152  Done
# 153  Done
# 154  Done
# 155  Done
# 156  Done
# 157  Done
# 158  Done
# 159  Done
# 160  Done
# 161  Done
# 162  Done
# 163  Done
# 164  Done
# 165  Done
# 166  Done
# 167  Done
# 168  Done
# 169  Done
# 170  Done
# 171  Done
# 172  Done
# 173  Done
# 174  Done
# 175  Done
# 176  Done
# 177  Done
# 178  Done
# 179  Done
# 180  Done
# 181  Done
# 182  Done
# 183  Done
# 184  Done
# 185  Done
# 186  Done
# 187  Done
# 188  Done
# 189  Done
# 190  Done
# 191  Done
# 192  Done
# 193  Done
# 194  Done
# 195  Done
# 196  Done
# 197  Done
# 198  Done
# 199  Done
# 200  Done
# ['ToyModelPlot0001.jpg', 'ToyModelPlot0002.jpg', 'ToyModelPlot0003.jpg', 'ToyModelPlot0004.jpg', 'ToyModelPlot0005.jpg', 'ToyModelPlot0006.jpg', 'ToyModelPlot0007.jpg', 'ToyModelPlot0008.jpg', 'ToyModelPlot0009.jpg', 'ToyModelPlot0010.jpg', 'ToyModelPlot0011.jpg', 'ToyModelPlot0012.jpg', 'ToyModelPlot0013.jpg', 'ToyModelPlot0014.jpg', 'ToyModelPlot0015.jpg', 'ToyModelPlot0016.jpg', 'ToyModelPlot0017.jpg', 'ToyModelPlot0018.jpg', 'ToyModelPlot0019.jpg', 'ToyModelPlot0020.jpg', 'ToyModelPlot0021.jpg', 'ToyModelPlot0022.jpg', 'ToyModelPlot0023.jpg', 'ToyModelPlot0024.jpg', 'ToyModelPlot0025.jpg', 'ToyModelPlot0026.jpg', 'ToyModelPlot0027.jpg', 'ToyModelPlot0028.jpg', 'ToyModelPlot0029.jpg', 'ToyModelPlot0030.jpg', 'ToyModelPlot0031.jpg', 'ToyModelPlot0032.jpg', 'ToyModelPlot0033.jpg', 'ToyModelPlot0034.jpg', 'ToyModelPlot0035.jpg', 'ToyModelPlot0036.jpg', 'ToyModelPlot0037.jpg', 'ToyModelPlot0038.jpg', 'ToyModelPlot0039.jpg', 'ToyModelPlot0040.jpg', 'ToyModelPlot0041.jpg', 'ToyModelPlot0042.jpg', 'ToyModelPlot0043.jpg', 'ToyModelPlot0044.jpg', 'ToyModelPlot0045.jpg', 'ToyModelPlot0046.jpg', 'ToyModelPlot0047.jpg', 'ToyModelPlot0048.jpg', 'ToyModelPlot0049.jpg', 'ToyModelPlot0050.jpg', 'ToyModelPlot0051.jpg', 'ToyModelPlot0052.jpg', 'ToyModelPlot0053.jpg', 'ToyModelPlot0054.jpg', 'ToyModelPlot0055.jpg', 'ToyModelPlot0056.jpg', 'ToyModelPlot0057.jpg', 'ToyModelPlot0058.jpg', 'ToyModelPlot0059.jpg', 'ToyModelPlot0060.jpg', 'ToyModelPlot0061.jpg', 'ToyModelPlot0062.jpg', 'ToyModelPlot0063.jpg', 'ToyModelPlot0064.jpg', 'ToyModelPlot0065.jpg', 'ToyModelPlot0066.jpg', 'ToyModelPlot0067.jpg', 'ToyModelPlot0068.jpg', 'ToyModelPlot0069.jpg', 'ToyModelPlot0070.jpg', 'ToyModelPlot0071.jpg', 'ToyModelPlot0072.jpg', 'ToyModelPlot0073.jpg', 'ToyModelPlot0074.jpg', 'ToyModelPlot0075.jpg', 'ToyModelPlot0076.jpg', 'ToyModelPlot0077.jpg', '